# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import defaultdict
from math import log
import json
from sklearn.utils import shuffle
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
# Out:
# Bad key "text.kerning_factor" on line 4 in
# d:\Users\96212\anaconda3\envs\ML\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
DATA_PATH = 'data/mushrooms.csv'
# DATA_PATH = '../data/data.xlsx'

# %% [markdown]
# # 1.数据

# %%
def createDataSet():
    dataSet = pd.read_csv(DATA_PATH)
    return dataSet

df_data = createDataSet()  # 创造示列数据
df_data = df_data[:]

# %%
# 蘑菇数据集把类别放到最后
cls = df_data.pop('class')
df_data.insert(loc=df_data.shape[1], column='class', value=cls, allow_duplicates=False)
df_data
# Out:
#      cap-shape cap-surface cap-color bruises gill-attachment gill-spacing  \
# 0            x           s         n       t               f            c
# 1            x           s         y       t               f            c
# 2            b           s         w       t               f            c
# 3            x           y         w       t               f            c
# 4            x           s         g       f               f            w
# ...        ...         ...       ...     ...             ...          ...
# 8119         k           s         n       f               a            c
# 8120         x           s         n       f               a            c
# 8121         f           s         n       f               a            c
# 8122         k           y         n       f               f            c
# 8123         x           s         n       f               a            c
#
#      gill-size gill-color stalk-shape stalk-root  ... stalk-color-above-ring  \
# 0            n          k           e          e  ...                      w
# 1            b          k           e          c  ...                      w
# 2            b          n           e          c  ...                      w
# 3            n          n           e          e  ...                      w
# 4            b          k           t          e  ...                      w
# ...        ...        ...         ...        ...  ...                    ...
# 8119         b          y           e          ?  ...                      o
# 8120         b          y           e          ?  ...                      o
# 8121         b          n           e          ?  ...                      o
# 8122         n          b           t          ?  ...                      w
# 8123         b          y           e          ?  ...                      o
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                         w         p          w           o         p
# 1                         w         p          w           o         p
# 2                         w         p          w           o         p
# 3                         w         p          w           o         p
# 4                         w         p          w           o         e
# ...                     ...       ...        ...         ...       ...
# 8119                      o         p          o           o         p
# 8120                      o         p          n           o         p
# 8121                      o         p          o           o         p
# 8122                      w         p          w           o         e
# 8123                      o         p          o           o         p
#
#      spore-print-color population habitat class
# 0                    k          s       u     p
# 1                    n          n       g     e
# 2                    n          n       m     e
# 3                    k          s       u     p
# 4                    n          a       g     e
# ...                ...        ...     ...   ...
# 8119                 b          c       l     e
# 8120                 b          v       l     e
# 8121                 b          c       l     e
# 8122                 w          v       l     p
# 8123                 o          c       l     e
#
# [8124 rows x 22 columns]

# %%
# df_data = shuffle(df_data)
df_data = df_data.reset_index(drop=True)
df_data
# Out:
#      cap-shape cap-surface cap-color bruises gill-attachment gill-spacing  \
# 0            x           s         n       t               f            c
# 1            x           s         y       t               f            c
# 2            b           s         w       t               f            c
# 3            x           y         w       t               f            c
# 4            x           s         g       f               f            w
# ...        ...         ...       ...     ...             ...          ...
# 8119         k           s         n       f               a            c
# 8120         x           s         n       f               a            c
# 8121         f           s         n       f               a            c
# 8122         k           y         n       f               f            c
# 8123         x           s         n       f               a            c
#
#      gill-size gill-color stalk-shape stalk-root  ... stalk-color-above-ring  \
# 0            n          k           e          e  ...                      w
# 1            b          k           e          c  ...                      w
# 2            b          n           e          c  ...                      w
# 3            n          n           e          e  ...                      w
# 4            b          k           t          e  ...                      w
# ...        ...        ...         ...        ...  ...                    ...
# 8119         b          y           e          ?  ...                      o
# 8120         b          y           e          ?  ...                      o
# 8121         b          n           e          ?  ...                      o
# 8122         n          b           t          ?  ...                      w
# 8123         b          y           e          ?  ...                      o
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                         w         p          w           o         p
# 1                         w         p          w           o         p
# 2                         w         p          w           o         p
# 3                         w         p          w           o         p
# 4                         w         p          w           o         e
# ...                     ...       ...        ...         ...       ...
# 8119                      o         p          o           o         p
# 8120                      o         p          n           o         p
# 8121                      o         p          o           o         p
# 8122                      w         p          w           o         e
# 8123                      o         p          o           o         p
#
#      spore-print-color population habitat class
# 0                    k          s       u     p
# 1                    n          n       g     e
# 2                    n          n       m     e
# 3                    k          s       u     p
# 4                    n          a       g     e
# ...                ...        ...     ...   ...
# 8119                 b          c       l     e
# 8120                 b          v       l     e
# 8121                 b          c       l     e
# 8122                 w          v       l     p
# 8123                 o          c       l     e
#
# [8124 rows x 22 columns]

# %% [markdown]
# # 2.划分训练集和验证集

# %%
slice = int(len(df_data) * 0.7)
slice
# Out:
# 5686

# %%
train_data = df_data[:slice]
train_label = df_data['class']
test_data = df_data[slice:]
test_label = test_data.pop('class')
test_data
# Out:
#      cap-shape cap-surface cap-color bruises gill-attachment gill-spacing  \
# 5686         f           s         b       t               f            c
# 5687         k           f         c       f               f            w
# 5688         x           s         g       t               f            c
# 5689         f           y         g       f               f            c
# 5690         x           y         e       f               f            c
# ...        ...         ...       ...     ...             ...          ...
# 8119         k           s         n       f               a            c
# 8120         x           s         n       f               a            c
# 8121         f           s         n       f               a            c
# 8122         k           y         n       f               f            c
# 8123         x           s         n       f               a            c
#
#      gill-size gill-color stalk-shape stalk-root  ...  \
# 5686         b          e           e          ?  ...
# 5687         n          w           e          b  ...
# 5688         b          p           t          b  ...
# 5689         b          h           e          b  ...
# 5690         n          b           t          ?  ...
# ...        ...        ...         ...        ...  ...
# 8119         b          y           e          ?  ...
# 8120         b          y           e          ?  ...
# 8121         b          n           e          ?  ...
# 8122         n          b           t          ?  ...
# 8123         b          y           e          ?  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 5686                        s                      e                      e
# 5687                        s                      w                      n
# 5688                        f                      w                      w
# 5689                        k                      p                      n
# 5690                        k                      p                      w
# ...                       ...                    ...                    ...
# 8119                        s                      o                      o
# 8120                        s                      o                      o
# 8121                        s                      o                      o
# 8122                        k                      w                      w
# 8123                        s                      o                      o
#
#      veil-type veil-color ring-number ring-type spore-print-color population  \
# 5686         p          w           t         e                 w          c
# 5687         p          w           o         e                 w          v
# 5688         p          w           o         p                 h          v
# 5689         p          w           o         l                 h          v
# 5690         p          w           o         e                 w          v
# ...        ...        ...         ...       ...               ...        ...
# 8119         p          o           o         p                 b          c
# 8120         p          n           o         p                 b          v
# 8121         p          o           o         p                 b          c
# 8122         p          w           o         e                 w          v
# 8123         p          o           o         p                 o          c
#
#      habitat
# 5686       w
# 5687       l
# 5688       u
# 5689       p
# 5690       l
# ...      ...
# 8119       l
# 8120       l
# 8121       l
# 8122       l
# 8123       l
#
# [2438 rows x 21 columns]

# %%
train_label
# Out:
# 0       p
# 1       e
# 2       e
# 3       p
# 4       e
#        ..
# 8119    e
# 8120    e
# 8121    e
# 8122    p
# 8123    e
# Name: class, Length: 8124, dtype: object

# %% [markdown]
# # 3.计算熵

# %%
# 计算数据集的熵，需D的最后一列为标签
def entropy(D):
    total_num = len(D)
    label_cnt = defaultdict(int)
    for i in range(total_num):
        label = D[i][-1]
        label_cnt[label] += 1
    ent = -sum([(cnt/total_num) * log(cnt/total_num, 2) for cnt in label_cnt.values()])
    return ent

# %% [markdown]
# # 4.条件熵

# %%
# 计算列索引为index的属性对集合D的条件熵
def cond_entropy(D, index):
    total_num = len(D)
    feature_sets = defaultdict(list)
    for i in range(total_num):
        feature = D[i][index]
        feature_sets[feature].append(D[i])
    cond_ent = sum([(len(d)/total_num) * entropy(d) for d in feature_sets.values()])
    return cond_ent

# %% [markdown]
# # 5.决策树节点

# %%
# 决策树节点类
class Node:
    def __init__(self, is_leaf, label=None, feature_idx=None, feature_name=None):
        self.is_leaf = is_leaf
        self.label = label  # 仅针对于叶子节点
        self.feature_idx = feature_idx  # 该节点特征对应的列索引，仅针对于非叶子节点
        self.feature_name = feature_name  # 该节点特征名，仅针对于非叶子节点
        self.sons = {}
        
    def add_son(self, feature_value, node):
        self.sons[feature_value] = node
        
    def predict(self, x):
        if self.is_leaf:
            return self.label
        features = []
        for feature in self.sons:
            features.append(feature)

        if x[self.feature_idx] not in features:
            return '未知'
        nextson = self.sons[x[self.feature_idx]]

        nextnode = x.copy()
        del nextnode[self.feature_idx]
        return nextson.predict(nextnode)
    
    def __repr__(self):
        s = {
            'feature:': self.feature_name,
            'label:': self.label,
            'sons:': self.sons
            }
        return '{}'.format(s)

# %% [markdown]
# # 6.BIN决策树模型

# %%
class BINTree:
    def __init__(self, epsilon=0.1):
        """
        epsilon: 决策树停止生长的信息增益阈值
        """
        # self.epsilon = epsilon
        self.decision_tree = None
        
    def fit(self, data):
        """data为dataframe格式"""
        # self.decision_tree生成的树
        self.decision_tree = self._train(data)
        return self.decision_tree
        
    def predict(self, x):
        if self.decision_tree:
            result = []
            # ss=0
            for i in x:
                # print(ss)
                # ss+=1
                # print(i)
                re = self.decision_tree.predict(list(i))
                result.append(re)
            return result
        
    def _get_max_gain_feature(self, D):
        num_features = len(D[0]) - 1
        ent_D = entropy(D)
        index, max_gain = 0, 0
        for i in range(num_features):
            cond_ent = cond_entropy(D, i)
            gain = ent_D - cond_ent  # 信息增益 = H(D) - H(D|A)
            if gain > max_gain:
                max_gain = gain
                index = i
        return index, max_gain
    
    def _generateGrainMatrix(self,data,k):
        '''生成粒矩阵'''
        a = data.iloc[:, k]  # 定位到决策属性列  data.shape[1] - 1 最后一列的索引
        a1 = pd.DataFrame(a)
        ls = a1.groupby(a).count()  # 分组计算
        l = list(ls.index)  # 索引拿出来 好瓜、坏瓜
        # 初始化决策属性矩阵，两行17列，全为0
        D = np.zeros([len(l), len(a)])
        # 生成粒矩阵
        for j in range(len(l)):
            for i in range(len(a)):
                if a[i] == l[j]:
                    D[j][i] = 1
        return D


    def _abc(self,dataSet):
        '''获得最大区分程度的条件属性'''
        # 把 list形式的dataSet转成 DataFrame 形式的data
        data = pd.DataFrame(dataSet)
        data = data.reset_index(drop=True)
        U = []
        U1 = []
        d = 0

        # 生成决策属性粒矩阵
        D0 = self._generateGrainMatrix(data,data.shape[1] - 1)

        # 生成条件属性矩阵
        for k in range(data.shape[1] - 1):
            # 得到条件粒矩阵
            D1 = self._generateGrainMatrix(data,k)
            # 决策属性粒矩阵转置与条件属性粒矩阵相乘
            D = np.dot(D1, D0.T)
            # 输出每一行是1的个数，也就是得到每个类的个数
            b = [ list(item).count(1) for item in D1 ]
            # 得到包含度矩阵
            GRM = D / np.array(b).reshape(1,-1).T     
            # 包含度矩阵取每行最大值
            D3 = [np.amax(item) for item in GRM]      
            # 将每行最大值集中在一个数组中
            U.extend(D3)  
            # 求平均值 按条件个数进行切片，求和后除以条件个数得到不同条件区分程度
            D4 = [(sum(U[d:d + len(D1)])) / len(D1)]
            U1.extend(D4)
            d = d + len(D1)
            
        # print(U1)
        N = U1.index(np.amax(U1))  # 取所有区分程度中的最大值所属类
        return N
            
    def _train(self, data):
        """递归构建决策树，data为dataframe格式"""
        y, feature_names = data.iloc[:, -1], data.columns[:-1]
        # 1.数据集中所有样本均属于同一类别，则停止生长
        if len(y.value_counts()) == 1:
            return Node(is_leaf=True, label=y.iloc[0])
        
        # 2.数据集中特征数量为空，则将包含实例数量最多的类作为该叶子节点的标签
        if len(feature_names) == 0:
            label = y.value_counts().sort_values(ascending=False).index[0]
            return Node(is_leaf=True, label=label)
        
        # 计算信息增益最大的特征
        # idx, max_gain = self._get_max_gain_feature(np.array(data))

        idx = self._abc(data)

        # # 3. 如果最大的信息增益小于设置的阈值，则停止生长
        # if max_gain < self.epsilon:
        #     label = y.value_counts().sort_values(ascending=False).index[0]
        #     return Node(is_leaf=True, label=label)
        
        target_feature = feature_names[idx]  # 当前节点特征
        
        # 创建节点
        curr_node = Node(is_leaf=False, feature_idx=idx, feature_name=target_feature)
        value_sets = data[target_feature].value_counts().index  # 该特征取值集合
        
        for value in value_sets:
            sub_data = data.loc[data[target_feature]==value].drop([target_feature], axis=1)
            # 4.递归生成子树
            sub_tree = self._train(sub_data)
            curr_node.add_son(value, sub_tree)
            
        return curr_node

# %% [markdown]
# # 7.开始拟合

# %%
dt = BINTree()
tree = dt.fit(train_data)
# tree
# print('决策树：{}'.format(tree))

# %% [markdown]
# # 9.做预测

# %%
test_pred = dt.predict(test_data.values)
# print('样本的预测结果：{}'.format(test_pred))

# %% [markdown]
# # 10.评估

# %%
from sklearn.metrics import classification_report
print(classification_report(test_pred,test_label))
# Out:
#               precision    recall  f1-score   support
#
#            e       0.17      1.00      0.30       106
#            p       0.98      0.84      0.91      2128
#           未知       0.00      0.00      0.00       204
#
#     accuracy                           0.78      2438
#    macro avg       0.38      0.61      0.40      2438
# weighted avg       0.86      0.78      0.80      2438
# d:\Users\96212\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Users\96212\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Users\96212\anaconda3\envs\ML\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix_model = confusion_matrix(test_pred, test_label)

# %%
import itertools

def cnf_matrix_plotter(cm,classes):
    '''
    传入混淆矩阵和标签名称列表，绘制混淆矩阵
    '''
    # plt.imshow (cm, interpolation='nearest', cmap=plt.cm.Greens)
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Oranges)
    plt.title('Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks,classes,rotation=45)
    plt.yticks(tick_marks,classes)
    
    threshold = cm.max() / 2.
    for i, j in itertools.product(range(cm. shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i,j],
        horizontalalignment="center",
        color="white" if cm[i,j] > threshold else "black",fontsize=25)
    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel(' Predicted Label')
    plt.show()

# %%
cnf_matrix_plotter(confusion_matrix_model,['e','p','unknow'])

# %% [markdown]
# # 8.k折交叉验证

# %%
from sklearn. metrics import roc_curve,auc
def BINTree_kfold(train_data,train_label,random_state,n_splits):
    score_result=[]
    true_result=[]
    pred_result=[]
    kfold = KFold(n_splits=n_splits, shuffle=True,random_state=random_state)
    # model = []
    for train_idx, val_idx in kfold.split(train_data):
        train_x = train_data.loc[train_idx].reset_index(drop=True)
        train_y = train_label.loc[train_idx].reset_index(drop=True)
        val_x = train_data.loc[val_idx].reset_index(drop=True)
        val_y = val_x.pop('class')
        treeModel = BINTree()
        treeModel.fit(train_x)
        # print(val_x)
        test_pred = treeModel.predict(val_x.values)
        # model.append(treeModel)
        true_result.append(val_y)
        pred_result.append(test_pred)
        score_result.append(accuracy_score(val_y, test_pred))
        random_state+=1
        
        # y_pred_quant = treeModel.predict(X_test)[:,1]
        # fpr,tpr,thresholds = roc_curve(val_y,test_pred)
        # auc = auc(fpr,tpr)
        # print("auc",auc)    
    return true_result,pred_result,score_result

# %%
n_splits=5
random_state = 100
train_data = df_data[:]
true_result,pred_result,score_result = BINTree_kfold(train_data,train_label,random_state,n_splits)

# %%
#test_data就是5折交叉验证中5次预测的结果
pre_y=pd.DataFrame(score_result).T
# #将5次预测的结果求取平均值，当然也可以使用其他的方法
pre_y['averge']=pre_y[[i for i in range(n_splits)]].mean(axis=1)
pre_y
# Out:
#      0    1         2    3    4    averge
# 0  1.0  1.0  0.998769  1.0  1.0  0.999754

# %% [markdown]
# # 9.评估

# %%
from sklearn.metrics import classification_report
idx = 2
print(classification_report(true_result[idx],pred_result[idx]))
# Out:
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       856
#            p       1.00      1.00      1.00       769
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %%
import itertools

def cnf_matrix_plotter(cm,classes):
    '''
    传入混淆矩阵和标签名称列表，绘制混淆矩阵
    '''
    # plt.imshow (cm, interpolation='nearest', cmap=plt.cm.Greens)
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Oranges)
    plt.title('Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks,classes,rotation=45)
    plt.yticks(tick_marks,classes)
    
    threshold = cm.max() / 2.
    for i, j in itertools.product(range(cm. shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i,j],
        horizontalalignment="center",
        color="white" if cm[i,j] > threshold else "black",fontsize=25)
    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel(' Predicted Label')
    plt.show()

# %%
from sklearn.metrics import confusion_matrix

idx = 2
confusion_matrix_model = confusion_matrix(true_result[idx],pred_result[idx])

cnf_matrix_plotter(confusion_matrix_model,['e','p','unknow'])
