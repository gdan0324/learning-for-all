# %%
# !pip install --upgrade pip
# !python -m pip install paddlepaddle-gpu==2.3.0.post101 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# !pip install --upgrade paddlenlp
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.6 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.1.2
#     Uninstalling pip-22.1.2:
#       Successfully uninstalled pip-22.1.2
# ...
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Looking in links: https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.0/566.0 MB 1.4 MB/s eta 0:00:0000:0100:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.7/373.7 kB 368.6 kB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: paddle-bfloat
#     Found existing installation: paddle-bfloat 0.1.7
#     Uninstalling paddle-bfloat-0.1.7:
#       Successfully uninstalled paddle-bfloat-0.1.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import os
import pandas as pd
from datasets import Dataset

# %%
train_json = pd.read_json('./data/train_data/train.json', lines=True)
test_json = pd.read_json('./data/test_data/test.json', lines=True)
dev_json = pd.read_json('./data/dev_data/dev.json', lines=True)

# %%
train_json.head()
# Out:
#                                          answer_list            title  \
# 0  [渝北区，重庆市辖区，属重庆主城区、重庆大都市区，地处重庆市西北部。东邻长寿区、南与江北区毗...         渝北区_百度百科
# 1  [幅员面积1452平方公里,辖11个镇19个街道(含两江新区直管区8个街道),建成区面积拓展...  渝北区情_重庆市渝北区人民政府
# 2       [渝北区幅员面积1452平方公里, 2、渝北区面积:  全区幅员面积1452平方公里。]    重庆主城九区面积- 本地宝
# 3                                     [总面积1452平方千米。]    渝北区 - 中文百科专业版
# 4  [渝北区面积:1452平方公里, 截至2013年底,渝北区面积1452平方公里,辖10街道、...  重庆市渝北区_行政区划信息参考
#
#                                                  url answer_start_list  \
# 0           https://baike.baidu.com/item/渝北区/2531151               [4]
# 1  http://www.ybq.gov.cn/zjyb/ybqq/201912/t201912...             [116]
# 2  http://wenda.bendibao.com/life/2020211/113197....         [53, 225]
# 3             http://zy.zwbk.org/index.php?title=渝北区             [212]
# 4  https://www.ajinshou.com/xingzhengquhua/xian.p...         [46, 225]
#
#                                             doc_text  query  \
# ...
