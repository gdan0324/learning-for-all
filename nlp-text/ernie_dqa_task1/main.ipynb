# %%
# 解压数据和模型到工作目录
# !tar zxvf /home/aistudio/data/data174964/ernie_dqa_task1.tar.gz -C /home/aistudio/work
# Out:
# ernie_dqa_task1/
# ernie_dqa_task1/applications/
# ernie_dqa_task1/applications/__init__.py
# ernie_dqa_task1/applications/models_hub/
# ernie_dqa_task1/applications/models_hub/ernie_3.0_base_ch_dir/
# ernie_dqa_task1/applications/models_hub/ernie_3.0_base_ch_dir/vocab.txt
# ernie_dqa_task1/applications/models_hub/ernie_3.0_base_ch_dir/model.meta
# ernie_dqa_task1/applications/models_hub/ernie_3.0_base_ch_dir/params/
# ernie_dqa_task1/applications/models_hub/ernie_3.0_base_ch_dir/params/encoder_layer_2_multi_head_att_value_fc.b_0_beta2_pow_acc_0
# ernie_dqa_task1/applications/models_hub/ernie_3.0_base_ch_dir/params/encoder_layer_6_ffn_fc_1.w_0
# ernie_dqa_task1/applications/models_hub/ernie_3.0_base_ch_dir/params/encoder_layer_5_multi_head_att_value_fc.w_0
# ernie_dqa_task1/applications/models_hub/ernie_3.0_base_ch_dir/params/encoder_layer_10_post_att_layer_norm_bias_beta1_pow_acc_0
# ernie_dqa_task1/applications/models_hub/ernie_3.0_base_ch_dir/params/@LR_DECAY_COUNTER@
# ...

# %%
# 进入基线代码目录
# %cd /home/aistudio/work/ernie_dqa_task1/applications/tasks/sequence_labeling
# 执行训练任务脚本
# !sh begin_train.sh
# Out:
# /home/aistudio/work/ernie_dqa_task1/applications/tasks/sequence_labeling

# %%
# 选择某step保存的模型，对开发集做预测，可修改json文件自行配置
# !python run_infer.py --param_path=./examples/seqlab_ernie_fc_ch_test_infer.json
# 评测开发集指标
# !sh evaluate.sh
# Out:
# INFO: 11-11 14:23:00: params.py:43 * 140681913689856 ./examples/seqlab_ernie_fc_ch_test_infer.json
# INFO: 11-11 14:23:00: params.py:52 * 140681913689856 {
#     "dataset_reader": {
#         "predict_reader": {
#             "config": {
#                 "batch_size": 16,
#                 "data_path": "./data/test_data",
#                 "epoch": 1,
#                 "need_data_distribute": false,
#                 "need_generate_examples": true,
#                 "sampling_rate": 1.0,
#                 "shuffle": false
#             },
#             "fields": [
#                 {
#                     "data_type": "string",
#                     "embedding": null,
#                     "max_seq_len": 512,
#                     "name": "text_a",
#                     "need_convert": true,
#                     "padding_id": 0,
#                     "reader": {
#                         "type": "ErnieTextFieldReader"
#                     },
#                     "tokenizer": {
# ...

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.
